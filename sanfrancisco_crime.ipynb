# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
# 5            Machine Learning             1629                  477
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136
# 5              74

# %%
df_data_1
sorted_df = df_data_1.sort_values('Very interested', axis=0, ascending=False)
new_df = df_data_1

new_df['Very interested'] = sorted_df['Very interested'].agg(lambda x: round((x/2233) * (100/1), 2))
new_df['Somewhat interested'] = sorted_df['Somewhat interested'].agg(lambda x: round(int(x)/2233 * 100/1, 2))
new_df['Not interested'] = sorted_df['Not interested'].agg(lambda x: round(int(x)/2233 * 100/1, 2))

# neu = sorted_df[1:].agg(lambda x: round(int(x)/2233, 2))  #sorted_df.groupby(['Very interested','Somewhat interested','Not interested']).agg(lambda x: x/230)
# neu
# we want it in the form of a percentage now. from 2,233

# %%
new_df.rename(columns = {'Unnamed: 0':''}, inplace = True)
#new_df.rename({new_df.columns[0]:"go now"}, inplace=True)
#new_df.columns[0]="go now"
new_df = new_df.sort_values(by=['Very interested'], ascending=False)
new_df
# Out:
#                                Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics            75.59                19.88
# 5            Machine Learning            72.95                21.36
# 3          Data Visualization            60.01                32.87
# 0   Big Data (Spark / Hadoop)            59.65                32.65
# 4               Deep Learning            56.56                34.48
# 2             Data Journalism            19.21                48.41
#
#    Not interested
# 1            2.69
# 5            3.31
# 3            4.57
# 0            5.69
# 4            6.09
# 2           27.32

# %%
new_df
# Out:
#                                Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics            75.59                19.88
# 5            Machine Learning            72.95                21.36
# 3          Data Visualization            60.01                32.87
# 0   Big Data (Spark / Hadoop)            59.65                32.65
# 4               Deep Learning            56.56                34.48
# 2             Data Journalism            19.21                48.41
#
#    Not interested
# 1            2.69
# 5            3.31
# 3            4.57
# 0            5.69
# 4            6.09
# 2           27.32

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

chart_colors=['#5cb85c','#5bc0de','#d9534f']
x_axis_names = ['Big Data (Spark / Hadoop)','Data Analysis / Statistics', 'Data Journalism','Data Visualization', 'Deep Learning', 'Machine Learning']

#bar_chart = new_df.plot(kind='bar', figsize=(20, 8),color=chart_colors)
new_df
# Out:
#                                Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics            75.59                19.88
# 5            Machine Learning            72.95                21.36
# 3          Data Visualization            60.01                32.87
# 0   Big Data (Spark / Hadoop)            59.65                32.65
# 4               Deep Learning            56.56                34.48
# 2             Data Journalism            19.21                48.41
#
#    Not interested
# 1            2.69
# 5            3.31
# 3            4.57
# 0            5.69
# 4            6.09
# 2           27.32

# %%
ax = new_df.plot(kind='bar', figsize=(20, 8),color=chart_colors, width=0.8, fontsize=14)

for index, value in enumerate(new_df["Very interested"]): 
    ax.text(index-0.3,value+0.5, str(value))

for index, value in enumerate(new_df["Somewhat interested"]): 
    ax.text(index-0.1,value+0.5, str(value))
    
for index, value in enumerate(new_df["Not interested"]): 
    ax.text(index+0.2,value+0.5, str(value))
#ax.text(0-8, 75.59, str("test"))
    
ax.set_title('Perdentage of Respondent\'s Interest in Data Science Areas',fontdict={'fontsize': 16})
ax.set_ylabel('Percentage of Interest')
ax.set_xlabel('Data Science Area')
ax.legend(loc=1)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)



#new_df.set_index('',drop=True,inplace=True)

# %% [markdown]
# # Part 2

# %%
import requests
import io

r = requests.get("https://cocl.us/sanfran_crime_dataset")
read_me_csv = io.StringIO(r.text)
df2 = pd.read_csv(read_me_csv)

# %%
df2
#pd["PdDistrict"]
# Out:
#         IncidntNum         Category  \
# 0        120058272      WEAPON LAWS
# 1        120058272      WEAPON LAWS
# 2        141059263         WARRANTS
# 3        160013662     NON-CRIMINAL
# 4        160002740     NON-CRIMINAL
# 5        160002869          ASSAULT
# 6        160003130   OTHER OFFENSES
# 7        160003259     NON-CRIMINAL
# 8        160003970         WARRANTS
# 9        160003641   MISSING PERSON
# 10       160086863    LARCENY/THEFT
# 11       160004053     NON-CRIMINAL
# 12       160073014   OTHER OFFENSES
# 13       140776777          ASSAULT
# 14       160004069         BURGLARY
# 15       160004150  STOLEN PROPERTY
# 16       160004241          ROBBERY
# 17       160004558          ASSAULT
# 18       160004655          ASSAULT
# 19       160004837    LARCENY/THEFT
# 20       160005421            FRAUD
# 21       160005750         WARRANTS
# 22       160005841    DRUG/NARCOTIC
# 23       160005841   OTHER OFFENSES
# 24       160006071          ASSAULT
# ...

# %%
#row_counts["Counts"] = pd.groupby('PdDistrict').count()['IncidntNum'].agg({'ID': })  # any column should do.They all have same values.
#row_counts.describe
test_me = df2['PdDistrict'].value_counts()
test_me = pd.DataFrame({'district':test_me.index, 'count':test_me.values})
test_me
# Out:
#    count    district
# 0  28445    SOUTHERN
# 1  20100    NORTHERN
# 2  19503     MISSION
# 3  17666     CENTRAL
# 4  14303     BAYVIEW
# 5  11594   INGLESIDE
# 6  11325     TARAVAL
# 7   9942  TENDERLOIN
# 8   8922    RICHMOND
# 9   8699        PARK

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Fetching package metadata ...

# %%
# define the world map centered around Canada with a low zoom level
world_map = folium.Map(location=[37.775421,-122.403405], zoom_start=12)

# !wget --quiet https://cocl.us/sanfran_geojson -O world_countries.json
world_geo = r'world_countries.json'
print('GeoJSON file downloaded!')

# %%
world_map.choropleth(
    geo_data=world_geo,
    data=test_me,
    columns=['district', 'count'],
    key_on='feature.properties.DISTRICT',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Reported Crimes in San Francisco'
)

# display world map
world_map
